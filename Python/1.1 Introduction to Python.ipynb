# %% [markdown]
# # Welcome To SCIP Python Track!
#
# Notebook author note: My name is Marisol and I am currently rising 3rd year PhD Student at the University of Southern California. I am in Dr. Michael Campbell's Human Evolutionary Genomics Lab. I am interested in using field-based, molecular, and computational methods to investigate the role of genomic, epigenomic, and environmental factors in the development of Type 2 Diabetes and related traits in Mexican American populations. I did my Bachelor degree at Cal State LA and my Masters at SF State. I have been involved in SCIP since 2022 as a participate in the Python track as well as coordinators and TA for R and Python.
#
# This week, we will focus on the introduction to Python. Please Note that some of the materials were used from Phelan Glenn's Google Colab. She is currently a PhD student at UCLA and a SF State Alumn and SCIP course developer.
#
#
#
# BEFORE we start, please create a folder in your google drive, and make a copy of this notebook. To copy the notebook just go click on file and then click on "save a copy in the drive". Once you click  so you can edit and run the code for your personal usage.

# %% [markdown]
# # Introduction to Python
#
# Chapter 1.1. Learning Goals
#  we will learn how how to use the
#
# *   To understand the usage of print
# *   To introduce the term String
# *   An introduction to troubleshooting (error message)
#
#
# Strings can be defined as a collections of characters (including letters, symbols, numbers and even whitespace).

# %%
print("Hello")
# Out:
# Hello

# %% [markdown]
# Strings can be represented by enclosing the characters with a single, double or triple quotes. ‘...’ “...”, """....""", etc.

# %%
#Using ""
print("Hello World")

#Using ''
print('Hello World')

#Using "".....""
print("""Hi, my name is Marisol and I am from Southern California...""")
# Out:
# Hello World
# Hello World
# Hi, my name is Marisol and I am from Southern California...

# %% [markdown]
# What will happen if you accidentally capitize the letter "P" in print?

# %%
Print("Hello World")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_20445/320528285.py in <cell line: 0>()
# ----> 1 Print("Hello World")
#
# NameError: name 'Print' is not defined

# %% [markdown]
# Within the error message, it will let you know what went wrong:
#
# For troubleshooting: As you are learning coding for the first time, AI platform is highly discouraged. genAI can be helpful tools AFTER you get your footing in coding, when you are just starting 1) practicing organically better helps cement learning longterm, and 2) it can be impossible to evaluate the correctness of an AI answer; sometimes it may be right, others it may be hallucinating.
#
# Google is your best friend. Copy and Paste: ( "NameError: name 'Print' is not defined ) into Google. Website like stack Overflow and Github is the BEST source if you are stuck in a code. Reaching out to your colleagues and mentors is ALSO the BEST source to ask for help.
#
#
#
#
#  ![Screenshot 2025-07-30 at 6.58.15 PM.png](data:image/png;base64,...)

# %% [markdown]
# In this case, the error message arises from case sensitivity, where the issue is that the character "p" was capitalized.

# %% [markdown]
# # Mini Excercise.
#
# A. What is your best activities to do in summer vacation?

# %%
#Hint use the print function
