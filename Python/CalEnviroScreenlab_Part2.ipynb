# %% [markdown]
# # Part 2: Your Turn

# %% [markdown]
# Create a new Python notebook in Google Colab with the same structure as this file and paste your finished work into it. You are more than welcome to use notebook, Don't forget to make a copy to so you can edit it.
#
# Then change the author names to your team members.
#
# You can keep the same section order: Welcome data explorers, Exploring the Data, Example analyses, Visualization Examples, Statistics Examples, Part Two, and Independent Group Analyses.

# %% [markdown]
# # Independent Group Analyses
#
# Now explore your own questions with your group. Everyone should contribute. Your goal is to ask and address at least 1 questions, and your final results should include visualizations and/or statistical output.
#
#
# You and your team should work together and interpret your results together.
#
# A shared code platform such as Codeshare can be useful for transferring code live, and a cloud notebook can also help with collaboration.

# %% [markdown]
# Independent Question 1

# %%
# Answer:

# %% [markdown]
# Question:

# %%
# Answer:

# %% [markdown]
# Prediction/Hypothesis:

# %%
#Answer:

# %% [markdown]
# Analysis:

# %%
# [add code blocks here]

# %% [markdown]
# Result:

# %%
# [add code blocks here]

# %% [markdown]
# Interpretation:

# %%
# Answer:
