# %% [markdown]
# # Boxplots in Python: A Guided Introduction
#
# In this section you will learn how to make and customize **boxplots** in Python using Matplotlib.
#
# Boxplots are useful because they show:
# - the median
# - the spread of the data
# - the middle 50% of values
# - possible outliers
#
# We will be using matplotlib. Matplotlib is a comprehensive, Python library used for creating static, animated, and interactive data visualizations. It serves as the foundational backbone for data plotting in Python, widely utilized in data science, machine learning, and scientific research
#
# Please first watch this 7min video on a introduction to Matplotlib before working on the assignment:
# https://youtu.be/2KY5AaFvWtE?si=cb-5KGZdhbFo4kMC
#
#
# More information on Matplotlib: https://matplotlib.org/stable/tutorials/pyplot.html
#
#
#
# ### Learning goals
# By the end of this lesson, you should be able to:
# - create a basic plot in Matplotlib
# - make a simple boxplot
# - understand how the boxplot syntax works
# - customize a more complex boxplot
# - make small changes to your own plot

# %% [markdown]
# ## Before you watch the workshop video

# %%
#Install matplotlib
# %pip install matplotlib

# %%
import matplotlib.pyplot as plt

numbers = [1, 2, 3, 4, 5]

plt.plot(numbers)
plt.title("A simple line plot")
plt.show()

# %% [markdown]
# ### What this code is doing
#
# - `import matplotlib.pyplot as plt` loads the plotting library
# - `numbers = [...]` creates a list of values
# - `plt.plot(numbers)` draws the graph
# - `plt.show()` displays it
#
# This is the same basic workflow you will use for boxplots:
# 1. store your data
# 2. choose a plotting command
# 3. customize the figure
# 4. display the plot

# %%
# A very simple boxplot example
import matplotlib.pyplot as plt

scores = [70, 75, 80, 82, 90]

plt.boxplot(scores)
plt.title("A simple boxplot")
plt.show()

# %% [markdown]
# ### How this connects to the more complex plots
#
# The boxplots below use the same basic idea as the simple example above.
#
# The code becomes longer because we:
# - compare multiple datasets
# - change figure size
# - add colors and labels
# - style whiskers, caps, and medians
#
# Before running the next section, try this:
#
# **Try it yourself:** change one number in the `scores` list above and run the boxplot again.
# What changes?

# %% [markdown]
# #Time for a Workshop!
#
# Host: Dr. Maria-Belen Perez-Ramirez (postdoctoral researcher at Stanford)
#
# Video: https://www.youtube.com/watch?v=qo2ycoRQzN8
#
# As you watch the video, pay attention to:
# 1. how data is stored in Python variables
# 2. how `plt.plot()` and `plt.boxplot()` are used
# 3. what parts of a boxplot represent
# 4. how labels and colors change the plot
#
# After the video, you will practice using the same ideas in the code below.
#
# Github Repository: https://github.com/zznbelen/boxplot
#
# *This repository includes a Colab notebook and solutions at the end.

# %%
#Test 1. to see if example works
# Import libraries
import matplotlib.pyplot as plt
import numpy as np


# Creating dataset
np.random.seed(10)

data_1 = np.random.normal(100, 10, 200)
data_2 = np.random.normal(90, 20, 200)
data_3 = np.random.normal(80, 30, 200)
data_4 = np.random.normal(70, 40, 200)
data = [data_1, data_2, data_3, data_4]

fig = plt.figure(figsize =(10, 7))

# Creating axes instance
ax = fig.add_axes([0, 0, 1, 1])

# Creating plot
bp = ax.boxplot(data)

# show plot
plt.show()

# %%
#Reducing to 2 boxex
# Import libraries
import matplotlib.pyplot as plt
import numpy as np

# Creating dataset
np.random.seed(10)

data_1 = np.random.normal(100, 10, 200)
data_2 = np.random.normal(90, 20, 200)

data = [data_1, data_2]

fig = plt.figure(figsize =(10, 7))

# Creating axes instance
ax = fig.add_axes([0, 0, 1, 1])

# Creating plot
bp = ax.boxplot(data)

# show plot
plt.show()

# %%
# Adding our neuronal counts
#Import libraries
import matplotlib.pyplot as plt
import numpy as np

Control = (1450, 1471, 1500, 1538, 1646, 1798, 1808, 1818, 1999, 2035)
Experiment = (521, 628, 675, 899, 993, 1400, 1700)

data = [Control, Experiment]

fig = plt.figure(figsize =(5, 3))

# Creating axes instance
#ax = fig.add_axes([.25, .25, .5, .5])
ax = fig.add_subplot()

# Adding title
plt.title("Number of NeuN neurons")

# Creating plot
bp = ax.boxplot(data)

# show plot
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/cbook/__init__.py:1376: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   X = np.atleast_1d(X.T if isinstance(X, np.ndarray) else np.asarray(X))

# %%
#test a more complex boxplot
# Import libraries
import matplotlib.pyplot as plt
import numpy as np

# Creating dataset
np.random.seed(10)
data_1 = np.random.normal(100, 10, 200)
data_2 = np.random.normal(90, 20, 200)
data_3 = np.random.normal(80, 30, 200)
data_4 = np.random.normal(70, 40, 200)
data = [data_1, data_2, data_3, data_4]

fig = plt.figure(figsize =(10, 7))
ax = fig.add_subplot(111)

# Creating axes instance
bp = ax.boxplot(data, patch_artist = True,
                notch ='True', vert = 0)

colors = ['#0000FF', '#00FF00',
          '#FFFF00', '#FF00FF']

for patch, color in zip(bp['boxes'], colors):
    patch.set_facecolor(color)

# changing color and linewidth of
# whiskers
for whisker in bp['whiskers']:
    whisker.set(color ='#8B008B',
                linewidth = 1.5,
                linestyle =":")

# changing color and linewidth of
# caps
for cap in bp['caps']:
    cap.set(color ='#8B008B',
            linewidth = 2)

# changing color and linewidth of
# medians
for median in bp['medians']:
    median.set(color ='red',
               linewidth = 3)

# changing style of fliers
for flier in bp['fliers']:
    flier.set(marker ='D',
              color ='#e7298a',
              alpha = 0.5)

# x-axis labels
ax.set_yticklabels(['data_1', 'data_2',
                    'data_3', 'data_4'])

# Adding title
plt.title("Customized box plot")

# Removing top axes and right axes
# ticks
ax.get_xaxis().tick_bottom()
ax.get_yaxis().tick_left()

# show plot
plt.show()

# %%
#adding our dataset to the complex example
# Creating dataset
Control = (1450, 1471, 1500, 1538, 1646, 1798, 1808, 1818, 1999, 2035)
Experiment = (521, 628, 675, 899, 993, 1400, 1700)

data = [Control, Experiment]

fig = plt.figure(figsize =(5, 3))
ax = fig.add_subplot(111)

# Creating axes instance
bp = ax.boxplot(data, patch_artist = True, notch = False, vert = 0)
# bp = ax.boxplot(data, notch ='False', vert = 1)


colors = ['#FFFF00', '#F000F0']

for patch, color in zip(bp['boxes'], colors):
    patch.set_facecolor(color)

# changing color and linewidth of
# whiskers
for whisker in bp['whiskers']:
    whisker.set(color ='#9B008B',
                linewidth = 3,
                linestyle =":")

# changing color and linewidth of
# caps
for cap in bp['caps']:
    cap.set(color ='#8B008B',
            linewidth = 2)

# changing color and linewidth of
# medians
for median in bp['medians']:
    median.set(color ='red',
               linewidth = 5)

# changing style of fliers
for flier in bp['fliers']:
    flier.set(marker ='D',
              color ='#e7298a',
              alpha = 0.9)

# x-axis labels
ax.set_yticklabels(['Control', 'Experiment'])

# Adding title
plt.title("Number of NeuN neurons")

# Removing top axes and right axes
# ticks
ax.get_xaxis().tick_bottom()
ax.get_yaxis().tick_left()

# show plot
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/cbook/__init__.py:1376: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   X = np.atleast_1d(X.T if isinstance(X, np.ndarray) else np.asarray(X))

# %%
#Solution to changing colors
# Creating dataset
Control = (1450, 1471, 1500, 1538, 1646, 1798, 1808, 1818, 1999, 2035)
Experiment = (521, 628, 675, 899, 993, 1400, 1700)

data = [Control, Experiment]

fig = plt.figure(figsize =(5, 3))
ax = fig.add_subplot(111)

# Creating axes instance
bp = ax.boxplot(data, patch_artist = True, notch = False, vert = 0)
# bp = ax.boxplot(data, notch ='False', vert = 1)


colors = ['blue', 'green']

for patch, color in zip(bp['boxes'], colors):
    patch.set_facecolor(color)

# changing color and linewidth of
# whiskers
for whisker in bp['whiskers']:
    whisker.set(color ='#9B008B',
                linewidth = 3,
                linestyle =":")

# changing color and linewidth of
# caps
for cap in bp['caps']:
    cap.set(color ='#8B008B',
            linewidth = 2)

# changing color and linewidth of
# medians
for median in bp['medians']:
    median.set(color ='red',
               linewidth = 5)

# changing style of fliers
for flier in bp['fliers']:
    flier.set(marker ='D',
              color ='#e7298a',
              alpha = 0.9)

# x-axis labels
ax.set_yticklabels(['Control', 'Experiment'])

# Adding title
plt.title("Number of NeuN neurons")

# Removing top axes and right axes
# ticks
ax.get_xaxis().tick_bottom()
ax.get_yaxis().tick_left()

# show plot
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/cbook/__init__.py:1376: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   X = np.atleast_1d(X.T if isinstance(X, np.ndarray) else np.asarray(X))

# %%
#solution to changing horizontal to vertical
# Creating dataset
Control = (1450, 1471, 1500, 1538, 1646, 1798, 1808, 1818, 1999, 2035)
Experiment = (521, 628, 675, 899, 993, 1400, 1700)

data = [Control, Experiment]

fig = plt.figure(figsize =(5, 3))
ax = fig.add_subplot(111)

# Creating axes instance
bp = ax.boxplot(data, patch_artist = True, notch = False, vert = 1)
# bp = ax.boxplot(data, notch ='False', vert = 1)


colors = ['#FFFF00', '#F000F0']

for patch, color in zip(bp['boxes'], colors):
    patch.set_facecolor(color)

# changing color and linewidth of
# whiskers
for whisker in bp['whiskers']:
    whisker.set(color ='#9B008B',
                linewidth = 3,
                linestyle =":")

# changing color and linewidth of
# caps
for cap in bp['caps']:
    cap.set(color ='#8B008B',
            linewidth = 2)

# changing color and linewidth of
# medians
for median in bp['medians']:
    median.set(color ='red',
               linewidth = 5)

# changing style of fliers
for flier in bp['fliers']:
    flier.set(marker ='D',
              color ='#e7298a',
              alpha = 0.9)

# x-axis labels
#ax.set_yticklabels(['Control', 'Experiment'])

# Adding title
plt.title("Number of NeuN neurons")

# Removing top axes and right axes
# ticks
ax.get_xaxis().tick_bottom()
ax.get_yaxis().tick_left()

# show plot
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/cbook/__init__.py:1376: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   X = np.atleast_1d(X.T if isinstance(X, np.ndarray) else np.asarray(X))

# %% [markdown]
# ## Try it yourself
#
# Choose one of the plots from above and make a small change:
#
# - change the plot title
# - change the box colors
# - switch from horizontal to vertical
# - add one more value to a dataset
#
# ### Reflection questions
# 1. Which group has the larger spread?
# 2. Which group has the higher median?
# 3. Why might a boxplot be better than just looking at a mean?
